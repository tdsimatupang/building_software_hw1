# %%
### ***GETTING STARTED***

###1. Load the data to a single DataFrame.
import pandas as pd

daily_shelter_proc = pd.read_csv("/Users/tdsim/OneDrive/Desktop/DSI/Assignment/Python Assignment 2/SIMATUPANG_TULUS_python_assignment2_orig.csv")

# %%
daily_shelter_proc = daily_shelter_proc.loc[daily_shelter_proc["LOCATION_CITY"] != "Toronto"]

daily_shelter_proc.head()
# Out:
#     _id       OCCUPANCY_DATE  ORGANIZATION_ID  \
# 3     4  2023-01-01T00:00:00               24
# 4     5  2023-01-01T00:00:00               24
# 5     6  2023-01-01T00:00:00               14
# 11   12  2023-01-01T00:00:00                1
# 12   13  2023-01-01T00:00:00                1
#
#                           ORGANIZATION_NAME  SHELTER_ID  \
# 3                  COSTI Immigrant Services          40
# 4                  COSTI Immigrant Services          40
# 5   Christie Ossington Neighbourhood Centre          22
# 11                          City of Toronto          53
# 12                          City of Toronto          53
#
#                       SHELTER_GROUP  LOCATION_ID  \
# 3            COSTI Reception Centre         1114
# 4            COSTI Reception Centre         1114
# 5   Christie Ossington Men's Hostel         1160
# 11               Birkdale Residence         1103
# 12               Birkdale Residence         1103
#
#                          LOCATION_NAME  LOCATION_ADDRESS LOCATION_POSTAL_CODE  \
# 3           COSTI Uptown Hotel Program   55 Hallcrown Pl              M2J 4R1
# 4           COSTI Uptown Hotel Program   55 Hallcrown Pl              M2J 4R1
# 5         CONC Etobicoke Hotel Program  445 Rexdale Blvd              M9W 6P8
# 11  SSHA North York West Hotel Program   1677 Wilson Ave              M3L 1A5
# 12  SSHA North York West Hotel Program   1677 Wilson Ave              M3L 1A5
#
#     ... OCCUPIED_BEDS UNOCCUPIED_BEDS  UNAVAILABLE_BEDS CAPACITY_ACTUAL_ROOM  \
# 3   ...           NaN             NaN               NaN                 76.0
# 4   ...           NaN             NaN               NaN                148.0
# 5   ...           NaN             NaN               NaN                142.0
# 11  ...           NaN             NaN               NaN                 12.0
# 12  ...           NaN             NaN               NaN                 83.0
#
#    CAPACITY_FUNDING_ROOM OCCUPIED_ROOMS UNOCCUPIED_ROOMS UNAVAILABLE_ROOMS  \
# 3                   83.0           76.0              0.0               7.0
# 4                  148.0          148.0              0.0               0.0
# 5                  152.0          142.0              0.0              10.0
# 11                  12.0           12.0              0.0               0.0
# 12                  83.0           83.0              0.0               0.0
#
#     OCCUPANCY_RATE_BEDS OCCUPANCY_RATE_ROOMS
# 3                   NaN                100.0
# 4                   NaN                100.0
# 5                   NaN                100.0
# 11                  NaN                100.0
# 12                  NaN                100.0
#
# [5 rows x 32 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

occupied = plt.scatter(range(len(daily_shelter_proc)), daily_shelter_proc['OCCUPIED_BEDS'], label='Occupied Beds')
unoccupied = plt.scatter(range(len(daily_shelter_proc)), daily_shelter_proc['UNOCCUPIED_BEDS'], label='Unoccupied Beds')

# Adding labels and title
plt.xlabel("Data Points")
plt.ylabel("Number of Beds")
plt.title("Occupied vs Unoccupied Beds")

# Add a legend
plt.legend()

# Add a grid
plt.grid()

plt.savefig('occ_vs_unocc.png')

# Show the plot
plt.show()
